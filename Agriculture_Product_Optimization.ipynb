# %% [markdown]
# # Introduction

# %% [markdown]
# In today's agricultural landscape, the convergence of technology and data science has catalyzed transformative advancements. This document examines the intersection of machine learning and agriculture, focusing on optimizing agricultural products. By leveraging machine learning algorithms, we aim to uncover insights and predictive patterns that enhance crop production, resource allocation, and decision-making processes. From predicting crop yields to detecting diseases and optimizing resource management, the potential applications of machine learning in agriculture are extensive. Through the analysis of relevant datasets and case studies, this document provides a comprehensive understanding of how machine learning can revolutionize agricultural practices, offering practical insights for implementing data-driven solutions in the agricultural sector.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from ipywidgets import interact

# %%
df = pd.read_csv("Crop.csv")
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %% [markdown]
# ### Check if there is any missing value

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
 #import missingno as msno
 #msno.matrix(df)

# %%
#pip install missingno

# %%
df['label'].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
sns.displot(x=df['K'],kde=True, bins=20, facecolor='#ffb03b',edgecolor='black', color='black')
plt.title("Potassium",size=20)
plt.show()

# %%
sns.displot(x=df['N'],kde=True, bins=20, facecolor='#ffb03b',edgecolor='black', color='black')
plt.title("Nitrogen",size=20)
plt.show()

# %%
mean = pd.Series.mean(df)
mean
# Out:
# C:\Users\Priyanshu\AppData\Local\Temp\ipykernel_12460\4274207447.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean = pd.Series.mean(df)
# N               50.551818
# P               53.362727
# K               48.149091
# temperature     25.616244
# humidity        71.481779
# ph               6.469480
# rainfall       103.463655
# dtype: float64

# %% [markdown]
# ### Checking values for individual crop

# %%
@interact
def summary(crops = list(df['label'].value_counts().index)):
    x = df[df['label']==crops]
    print("###################################")
    print("Nitrogen")
    print("Min: ",x['N'].min())
    print("Avg: ",x['N'].mean())
    print("Max: ",x['N'].max())
    print("###################################")
    print("Phosphorous")
    print("Min: ",x['P'].min())
    print("Avg: ",x['P'].mean())
    print("Max: ",x['P'].max())
    print("###################################")
    print("Potassium")
    print("Min: ",x['K'].min())
    print("Avg: ",x['K'].mean())
    print("Max: ",x['K'].max())
    print("###################################")
    print("Temperature")
    print("Min: ",x['temperature'].min())
    print("Avg: ",x['temperature'].mean())
    print("Max: ",x['temperature'].max())
    print("###################################")
    print("Humidity")
    print("Min: ",x['humidity'].min())
    print("Avg: ",x['humidity'].mean())
    print("Max: ",x['humidity'].max())
    print("###################################")
    print("PH")
    print("Min: ",x['ph'].min())
    print("Avg: ",x['ph'].mean())
    print("Max: ",x['ph'].max())
    print("###################################")
    print("Rainfall")
    print("Min: ",x['rainfall'].min())
    print("Avg: ",x['rainfall'].mean())
    print("Max: ",x['rainfall'].max())
# Out:
# interactive(children=(Dropdown(description='crops', options=('rice', 'maize', 'jute', 'cotton', 'coconut', 'pa…

# %% [markdown]
# ### Checking values for individual weather

# %%
@interact
def compare(conditions = ['N','P','K','temperature','ph','humidity','rainfall']):
    list = df.label.values.tolist()
    list = np.unique(list)
    
    lst = ['rice','mango']
    for i in list:
        print(i.capitalize()+ " : "+ format(df[(df['label']==i)][conditions].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %% [markdown]
# ### Check the values higher and lower than average

# %%
@interact
def compare(conditions = ['N','P','K','temperature','ph','humidity','rainfall']):
    print("Greater than Avg")
    print(df[df[conditions] > df[conditions].mean()]['label'].unique())
    print("\n")
    print("Less than Avg")
    print(df[df[conditions] <= df[conditions].mean()]['label'].unique())
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %% [markdown]
# ### Graphs for each weather condition

# %% [markdown]
# ### Seasonal Crops

# %%
fig,axes = plt.subplots(3,3,figsize=(18, 8))

plt.subplot(2,3,1)
sns.distplot(df['N'],color="black")
plt.xlabel("Ratio of Nitrogen",fontsize = 12)
plt.grid()

plt.subplot(2,3,2)
sns.distplot(df['P'],color="black")
plt.xlabel("Ratio of Phosphorous",fontsize = 12)
plt.grid()

plt.subplot(2,3,3)
sns.distplot(df['K'],color="black")
plt.xlabel("Ratio of Potassium",fontsize = 12)
plt.grid()

plt.subplot(2,3,4)
sns.distplot(df['temperature'],color="black")
plt.xlabel("Ratio of Temperature",fontsize = 12)
plt.grid()

plt.subplot(2,3,5)
sns.distplot(df['rainfall'],color="black")
plt.xlabel("Ratio of Rainfall",fontsize = 12)
plt.grid()

plt.subplot(2,3,6)
sns.distplot(df['humidity'],color="black")
plt.xlabel("Ratio of Humidity",fontsize = 12)
plt.grid()
# Out:
# C:\Users\Priyanshu\.ipython\anaconda3.0\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Priyanshu\.ipython\anaconda3.0\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df.drop(columns=['label']))
plt.title('Box Plot of Numerical Features')
plt.xlabel('Value')
plt.ylabel('Feature')
plt.show()

# %%
sns.catplot(data=df, x='label', y='temperature', kind='box', height=10, aspect=20/8.27)
# plt.xticks(rotation='vertical')
plt.title("Temperature", size=20)
plt.show()

# %%
sns.relplot(x='rainfall',y='temperature',data=df,kind='scatter',hue='label',height=5)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'df' is your DataFrame containing the label column
# For demonstration purposes, let's create a sample DataFrame


df = pd.DataFrame(df)

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the label column
df['Label_encoded'] = label_encoder.fit_transform(df['label'])

# Display the DataFrame with encoded labels
print(df)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label  \
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
#       Label_encoded
# 0                20
# 1                20
# 2                20
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True)
plt.title('Heatmap of Correlation ')
plt.show()

# %%
df.drop(columns=['Label_encoded'], inplace=True)
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
plt.figure(figsize=(20, 6))
sns.scatterplot(x='label', y='K', data=df)
plt.title('Scatter Plot of K vs Label')
plt.xlabel('Label')
plt.ylabel('K')
plt.show()

# %%
print("Summer Crops")
print(df[(df['temperature']>30) & (df['humidity']>50)]['label'].unique())
print("\n")
print("Winter Crops")
print(df[(df['temperature']<20) & (df['humidity']>30)]['label'].unique())
print("\n")
print("Rainy Crops")
print(df[(df['rainfall']>200) & (df['humidity']>30)]['label'].unique())
print("\n")
# Out:
# Summer Crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
#
#
# Winter Crops
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
#
#
# Rainy Crops
# ['rice' 'papaya' 'coconut']

# %%
plt.figure(figsize=(20, 8))
sns.violinplot(x='label', y='temperature', data=df)
plt.title('Box Plot of Temperature by Label')
plt.xlabel('Label')
plt.ylabel('Temperature (°C)')
plt.show()

# %% [markdown]
# ### Applying Kmeans clustering

# %%
from sklearn.cluster import KMeans
# removing the label column
x = df.drop(['label'],axis=1)

# selecting all the values of the data
x=x.values

# checking the shape
print(x.shape)
# Out:
# (2200, 7)

# %%
"""plt.rcParams['figure.figsize'] = (10,4)
    
wcss = []
for i in range(1,11):
    km = KMeans(n_clusters = i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    km.fit(x)
    wcss.append(km.inertia_)

# plotting the results
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method', fontsize = 20)
plt.xlabel('No. of clusters')
plt.ylabel('wcss')
plt.show()"""
# Out:
# "plt.rcParams['figure.figsize'] = (10,4)\n    \nwcss = []\nfor i in range(1,11):\n    km = KMeans(n_clusters = i,init='k-means++',max_iter=300,n_init=10,random_state=0)\n    km.fit(x)\n    wcss.append(km.inertia_)\n\n# plotting the results\nplt.plot(range(1,11),wcss)\nplt.title('The Elbow Method', fontsize = 20)\nplt.xlabel('No. of clusters')\nplt.ylabel('wcss')\nplt.show()"

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       2.1.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# ...

# %%
"""km = KMeans(n_clusters = 4,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_means = km.fit_predict(x)

#finding the results
a = df['label']
y_means = pd.DataFrame(y_means)
y_means
z = pd.concat([y_means,a],axis =1)
z = z.rename(columns = {0:'cluster'})
z

#check each cluster
print("1st Cluster: ",z[z['cluster']==0]['label'].unique())
print("2nd Cluster: ",z[z['cluster']==1]['label'].unique())
print("3rd Cluster: ",z[z['cluster']==2]['label'].unique())
print("4th Cluster: ",z[z['cluster']==3]['label'].unique())"""
# Out:
# 'km = KMeans(n_clusters = 4,init=\'k-means++\',max_iter=300,n_init=10,random_state=0)\ny_means = km.fit_predict(x)\n\n#finding the results\na = df[\'label\']\ny_means = pd.DataFrame(y_means)\ny_means\nz = pd.concat([y_means,a],axis =1)\nz = z.rename(columns = {0:\'cluster\'})\nz\n\n#check each cluster\nprint("1st Cluster: ",z[z[\'cluster\']==0][\'label\'].unique())\nprint("2nd Cluster: ",z[z[\'cluster\']==1][\'label\'].unique())\nprint("3rd Cluster: ",z[z[\'cluster\']==2][\'label\'].unique())\nprint("4th Cluster: ",z[z[\'cluster\']==3][\'label\'].unique())'

# %%
import pickle
with open('kmeans_model.pkl', 'wb') as f:
    pickle.dump(km, f)

# %% [markdown]
# ### Split dataset for training model

# %%
y = df['label']
x = df.drop(['label'],axis = 1)
print(x.shape)
print(y.shape)
# Out:
# (2200, 7)
# (2200,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
# Out:
# C:\Users\Priyanshu\.ipython\anaconda3.0\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
with open('logistic_regression_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
from sklearn.metrics import confusion_matrix

plt.rcParams['figure.figsize'] = (10,10)
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True,cmap = 'Wistia')
plt.title('Confusion matrix for logistic regression',fontsize = 15)
plt.show()

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.86      0.82      0.84        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       0.89      1.00      0.94        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.84      1.00      0.91        21
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.94      0.94      0.94        17
#        maize       0.94      0.89      0.91        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       0.88      0.92      0.90        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        23
# ...

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
pred = model.predict(np.array(np.array([[99,15,27,27,56,6,200]])))
print(pred)
# Out:
# ['coffee']
# C:\Users\Priyanshu\.ipython\anaconda3.0\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Conclusion

# %% [markdown]
# The visualization and analysis of data through scatter plots provide valuable insights into the relationship between two variables. Through this graphical representation, patterns, trends, and correlations within the data can be discerned, aiding in decision-making processes and hypothesis validation. Scatter plots offer a simple yet powerful means of exploring and understanding data distributions, facilitating the identification of outliers, clusters, and potential anomalies. By visualizing the relationship between variables, stakeholders can make informed decisions, devise strategies, and uncover opportunities for further exploration or investigation. Thus, scatter plots serve as indispensable tools in the toolkit of data analysts, researchers, and decision-makers, enabling them to extract actionable insights from complex datasets.
